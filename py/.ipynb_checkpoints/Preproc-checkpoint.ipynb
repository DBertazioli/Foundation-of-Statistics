# %%
import pandas as pd
import re

# %%
data=pd.read_csv("../data/laptops.csv",encoding = "ISO-8859-1",index_col=0)

# %%
data["Cpu"].head()
# Out:
# 1          Intel Core i5 2.3GHz
# 2          Intel Core i5 1.8GHz
# 3    Intel Core i5 7200U 2.5GHz
# 4          Intel Core i7 2.7GHz
# 5          Intel Core i5 3.1GHz
# Name: Cpu, dtype: object

# %%
# %%timeit
Peso = []
for w in data["Weight"]:
    Peso.append(float(re.split("kg",w)[0]))
# Out:
# 937 µs ± 6.75 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
Mem = []
for r in data["Ram"]:
    Mem.append(int(re.split("GB",r)[0]))

# %%
data["Weight"]=Peso
data["Ram"]=Mem

# %%
#Per il futuro, ti consiglio di usare la funzione map (simile ad apply su R) per manipolare colonne dei df, è memory-efficient, parallelizzabile,e ottimizzata low level
#Tipo

#data["Weight2"]=data.Weight.map(lambda x: float(re.split("kg",x)[0]))
# Out:
# 1.18 ms ± 10.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
data.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 1   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 2   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 3      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 4   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 5   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 1        Intel Core i5 2.3GHz    8            128GB SSD
# 2        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 3  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 4        Intel Core i7 2.7GHz   16            512GB SSD
# 5        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 1  Intel Iris Plus Graphics 640  macOS    1.37      1339.69
# 2        Intel HD Graphics 6000  macOS    1.34       898.94
# 3         Intel HD Graphics 620  No OS    1.86       575.00
# 4            AMD Radeon Pro 455  macOS    1.83      2537.45
# 5  Intel Iris Plus Graphics 650  macOS    1.37      1803.60

# %%
data.loc[max(data.groupby("Company")["Price_euros"].idxmax())]
# Out:
# Company                                    Acer
# Product                         Predator G9-793
# TypeName                                 Gaming
# Inches                                     17.3
# ScreenResolution    IPS Panel Full HD 1920x1080
# Cpu                 Intel Core i7 7700HQ 2.8GHz
# Ram                                          16
# Memory                     256GB SSD +  1TB HDD
# Gpu                     Nvidia GeForce GTX 1070
# OpSys                                Windows 10
# Weight                                      4.2
# Price_euros                                2599
# Name: 1207, dtype: object

# %%
df = data.rename({"Price_euros": 'Price'}, axis=1)  # new method

# %%
df["Memory"].unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '32GB Flash Storage', '128GB SSD +  1TB HDD',
#        '256GB SSD +  256GB SSD', '64GB Flash Storage',
#        '256GB SSD +  1TB HDD', '256GB SSD +  2TB HDD', '32GB SSD',
#        '2TB HDD', '64GB SSD', '1.0TB Hybrid', '512GB SSD +  1TB HDD',
#        '1TB SSD', '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid', '1.0TB HDD',
#        '512GB SSD +  1.0TB Hybrid', '256GB SSD +  1.0TB Hybrid'],
#       dtype=object)

# %%
#Ghz=re.compile("\d(.\d)*GHz")
Ghz=re.compile("\d(\.\d+)*GHz")

# %%
Ghz.search(df["Cpu"][383]).group()
# Out:
# '1.60GHz'

# %%
proc=df["Cpu"]

# %%
Cpu=[]
for i in proc:
    Cpu.append(Ghz.search(i).group())

# %%
df["Frequenza"]= Cpu

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 1   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 2   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 3      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 4   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 5   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 1        Intel Core i5 2.3GHz    8            128GB SSD
# 2        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 3  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 4        Intel Core i7 2.7GHz   16            512GB SSD
# 5        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight    Price Frequenza
# 1  Intel Iris Plus Graphics 640  macOS    1.37  1339.69    2.3GHz
# 2        Intel HD Graphics 6000  macOS    1.34   898.94    1.8GHz
# 3         Intel HD Graphics 620  No OS    1.86   575.00    2.5GHz
# 4            AMD Radeon Pro 455  macOS    1.83  2537.45    2.7GHz
# 5  Intel Iris Plus Graphics 650  macOS    1.37  1803.60    3.1GHz

# %%
Res = re.compile("\d+x\d+")
Risol = []
for i in df["ScreenResolution"]:
    Risol.append(Res.search(i).group())

# %%
df["Risoluzione"]= Risol

# %%
Res = re.compile("(\d+)x(\d+)")

# %%
Pixel = []
for i in df["Risoluzione"]:
    G = Res.search(i)
    Tot=int(G.group(1))*int(G.group(2))
    Pixel.append(Tot)

# %%
df["Pixel"]= Pixel

# %%
re.compile
# Out:
# <function re.compile(pattern, flags=0)>

# %%
df2 = df

# %%
w=re.compile("SSD")
SSD = []
for i in df["Memory"]:
    if (w.findall(i)==[]): 
        SSD.append(False)
    else: SSD.append(True)

# %% [markdown]
# ### Creo colonna Frequenza

# %%
Freq = []
for r in df2["Frequenza"]:
    Freq.append(float(re.split("GHz",r)[0]))
df2["Frequenza"]= Freq

# %%
df2.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 1   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 2   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 3      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 4   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 5   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 1        Intel Core i5 2.3GHz    8            128GB SSD
# 2        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 3  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 4        Intel Core i7 2.7GHz   16            512GB SSD
# 5        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight    Price  Frequenza  \
# 1  Intel Iris Plus Graphics 640  macOS    1.37  1339.69        2.3
# 2        Intel HD Graphics 6000  macOS    1.34   898.94        1.8
# 3         Intel HD Graphics 620  No OS    1.86   575.00        2.5
# 4            AMD Radeon Pro 455  macOS    1.83  2537.45        2.7
# 5  Intel Iris Plus Graphics 650  macOS    1.37  1803.60        3.1
#
#   Risoluzione    Pixel  SolidStateDisk
# 1   2560x1600  4096000            True
# 2    1440x900  1296000           False
# 3   1920x1080  2073600            True
# 4   2880x1800  5184000            True
# 5   2560x1600  4096000            True

# %%
df2.to_csv("Laptop2.csv")

# %%
df2.groupby("Memory")["Price"].max()
# Out:
# Memory
# 1.0TB HDD                         659.00
# 1.0TB Hybrid                     1099.00
# 128GB Flash Storage              1099.00
# 128GB HDD                         590.00
# 128GB SSD                        1599.00
# 128GB SSD +  1TB HDD             3012.77
# 128GB SSD +  2TB HDD              985.00
# 16GB Flash Storage                459.90
# 16GB SSD                          265.00
# 180GB SSD                        1364.00
# 1TB HDD                          2899.00
# 1TB HDD +  1TB HDD                621.45
# 1TB SSD                          6099.00
# 1TB SSD +  1TB HDD               3659.40
# 240GB SSD                        3100.00
# 256GB Flash Storage              2139.97
# 256GB SSD                        4389.00
# 256GB SSD +  1.0TB Hybrid        2749.99
# 256GB SSD +  1TB HDD             3149.00
# 256GB SSD +  256GB SSD           1298.00
# 256GB SSD +  2TB HDD             2449.00
# 256GB SSD +  500GB HDD           2103.34
# 2TB HDD                           989.99
# 32GB Flash Storage                659.00
# 32GB HDD                          265.00
# 32GB SSD                          389.00
# 500GB HDD                        1907.99
# 508GB Hybrid                     1002.00
# 512GB Flash Storage              1279.00
# 512GB SSD                        5499.00
# 512GB SSD +  1.0TB Hybrid        3240.00
# 512GB SSD +  1TB HDD             3890.00
# 512GB SSD +  256GB SSD           1607.96
# 512GB SSD +  2TB HDD             2649.00
# 512GB SSD +  512GB SSD           1499.00
# 64GB Flash Storage               1159.00
# 64GB Flash Storage +  1TB HDD    1993.00
# 64GB SSD                          277.99
# 8GB SSD                          2249.00
# Name: Price, dtype: float64

# %%
df2["Company"].unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'Chuwi', 'MSI',
#        'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %%
df2.loc[df2["Price"].idxmax()]
# Out:
# Company                                           Razer
# Product                                       Blade Pro
# TypeName                                         Gaming
# Inches                                             17.3
# ScreenResolution    4K Ultra HD / Touchscreen 3840x2160
# Cpu                         Intel Core i7 7820HK 2.9GHz
# Ram                                                  32
# Memory                                          1TB SSD
# Gpu                             Nvidia GeForce GTX 1080
# OpSys                                        Windows 10
# Weight                                             3.49
# Price                                              6099
# Frequenza                                           2.9
# Risoluzione                                   3840x2160
# Pixel                                           8294400
# SolidStateDisk                                     True
# Name: 200, dtype: object

# %%
df2.loc[df2.groupby("TypeName")["Price"].idxmin()]
# Out:
#      Company                                  Product            TypeName  \
# 319     Asus                            VivoBook Flip  2 in 1 Convertible
# 92      Asus  FX550IK-DM018T (FX-9830P/8GB/1TB/Radeon              Gaming
# 1233    Acer         C740-C9QX (3205U/2GB/32GB/Chrome             Netbook
# 1135    Vero         V131 (X5-Z8350/4GB/32GB/FHD/W10)            Notebook
# 402       HP     15-BW004nv (A9-9420/4GB/256GB/Radeon           Ultrabook
# 393     Dell                           Precision 3510         Workstation
#
#       Inches      ScreenResolution                                   Cpu  Ram  \
# 319     11.6  Touchscreen 1366x768  Intel Celeron Dual Core N3350 1.1GHz    2
# 92      15.6     Full HD 1920x1080                     AMD FX 9830P 3GHz    8
# 1233    11.6              1366x768  Intel Celeron Dual Core 3205U 1.5GHz    2
# 1135    13.3     Full HD 1920x1080           Intel Atom X5-Z8350 1.44GHz    4
# 402     15.6     Full HD 1920x1080               AMD A9-Series 9420 3GHz    4
# 393     15.6     Full HD 1920x1080           Intel Core i5 6440HQ 2.6GHz    8
#
#                   Memory                    Gpu       OpSys  Weight   Price  \
# 319   32GB Flash Storage  Intel HD Graphics 500  Windows 10    1.10   275.0
# 92               1TB HDD      AMD Radeon RX 560  Windows 10    2.45   699.0
# 1233            32GB SSD      Intel HD Graphics   Chrome OS    1.30   174.0
# 1135  32GB Flash Storage  Intel HD Graphics 400  Windows 10    1.35   196.0
# 402            256GB SSD         AMD Radeon 520  Windows 10    1.91   499.0
# 393            500GB HDD     AMD FirePro W5130M  Windows 10    2.23  1369.0
#
#       Frequenza Risoluzione    Pixel  SolidStateDisk
# 319        1.10    1366x768  1049088           False
# 92         3.00   1920x1080  2073600           False
# 1233       1.50    1366x768  1049088            True
# 1135       1.44   1920x1080  2073600           False
# 402        3.00   1920x1080  2073600            True
# 393        2.60   1920x1080  2073600           False

# %%
df2.loc[df2.groupby("Company")["Price"].idxmax()]
# Out:
#         Company                        Product     TypeName  Inches  \
# 1207       Acer                Predator G9-793       Gaming    17.3
# 18        Apple                    MacBook Pro    Ultrabook    15.4
# 1081       Asus                     ROG G701VO       Gaming    17.3
# 428       Chuwi                   LapBook 12.3     Notebook    12.3
# 731        Dell                   Alienware 17       Gaming    17.3
# 630     Fujitsu                  LifeBook A557     Notebook    15.6
# 444      Google                Pixelbook (Core    Ultrabook    12.3
# 758          HP                       Zbook 17  Workstation    17.3
# 219      Huawei                     MateBook X    Ultrabook    13.0
# 686          LG                    Gram 15Z975    Ultrabook    15.6
# 617      Lenovo                   Thinkpad P51     Notebook    15.6
# 181         MSI                GT80S 6QF-074US       Gaming    18.4
# 587    Mediacom                 SmartBook Edge     Notebook    14.0
# 456   Microsoft                 Surface Laptop    Ultrabook    13.5
# 200       Razer                      Blade Pro       Gaming    17.3
# 885     Samsung                     Notebook 9    Ultrabook    15.0
# 498     Toshiba              Portege X30-D-10L    Ultrabook    13.3
# 195        Vero  K147 (N3350/4GB/32GB/FHD/W10)     Notebook    14.0
# 521      Xiaomi                    Mi Notebook     Notebook    15.6
#
#                          ScreenResolution  \
# 1207          IPS Panel Full HD 1920x1080
# 18     IPS Panel Retina Display 2880x1800
# 1081          IPS Panel Full HD 1920x1080
# 428    IPS Panel Retina Display 2736x1824
# 731                 4K Ultra HD 3840x2160
# 630                              1366x768
# 444                 Touchscreen 2400x1600
# 758           IPS Panel Full HD 1920x1080
# 219           IPS Panel Full HD 2160x1440
# 686           IPS Panel Full HD 1920x1080
# 617       IPS Panel 4K Ultra HD 3840x2160
# 181                     Full HD 1920x1080
# 587           IPS Panel Full HD 1920x1080
# 456                 Touchscreen 2256x1504
# 200   4K Ultra HD / Touchscreen 3840x2160
# 885                     Full HD 1920x1080
# 498       Full HD / Touchscreen 1920x1080
# 195           IPS Panel Full HD 1920x1080
# 521           IPS Panel Full HD 1920x1080
#
#                                        Cpu  Ram                Memory  \
# 1207           Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 18                    Intel Core i7 2.9GHz   16             512GB SSD
# 1081           Intel Core i7 6820HK 2.7GHz   64               1TB SSD
# 428   Intel Celeron Quad Core N3450 1.1GHz    6    64GB Flash Storage
# 731            Intel Core i7 7700HQ 2.8GHz   32    1TB SSD +  1TB HDD
# 630             Intel Core i5 7200U 2.5GHz    8             256GB SSD
# 444              Intel Core i7 7Y75 1.3GHz   16             512GB SSD
# 758          Intel Xeon E3-1535M v5 2.9GHz   16             256GB SSD
# 219             Intel Core i7 7500U 2.7GHz    8             512GB SSD
# 686             Intel Core i7 8550U 1.8GHz    8             512GB SSD
# 617          Intel Xeon E3-1535M v6 3.1GHz   32               1TB SSD
# 181            Intel Core i7 6920HQ 2.9GHz   32  512GB SSD +  1TB HDD
# 587   Intel Celeron Quad Core N3450 1.1GHz    4              32GB SSD
# 456             Intel Core i7 7660U 2.5GHz   16             512GB SSD
# 200            Intel Core i7 7820HK 2.9GHz   32               1TB SSD
# 885             Intel Core i7 7500U 2.7GHz   16             256GB SSD
# 498             Intel Core i7 7500U 2.7GHz   32             512GB SSD
# 195   Intel Celeron Dual Core N3350 1.1GHz    4    32GB Flash Storage
# 521             Intel Core i7 8550U 1.8GHz   16             256GB SSD
#
#                                Gpu         OpSys  Weight    Price  Frequenza  \
# 1207       Nvidia GeForce GTX 1070    Windows 10    4.20  2599.00        2.8
# 18              AMD Radeon Pro 560         macOS    1.83  2858.00        2.9
# 1081       Nvidia GeForce GTX 980     Windows 10    3.58  3975.00        2.7
# 428          Intel HD Graphics 500    Windows 10    1.40   449.00        1.1
# 731        Nvidia GeForce GTX 1070    Windows 10    4.36  3659.40        2.8
# 630          Intel HD Graphics 620    Windows 10    2.20   799.00        2.5
# 444          Intel HD Graphics 615     Chrome OS    1.10  2199.00        1.3
# 758           Nvidia Quadro M2000M     Windows 7    3.00  4389.00        2.9
# 219          Intel HD Graphics 620    Windows 10    1.05  1499.00        2.7
# 686          Intel HD Graphics 620    Windows 10    1.09  2299.00        1.8
# 617           Nvidia Quadro M2200M    Windows 10    2.50  4899.00        3.1
# 181             Nvidia GTX 980 SLI    Windows 10    4.40  2799.00        2.9
# 587          Intel HD Graphics 500    Windows 10    1.45   389.00        1.1
# 456   Intel Iris Plus Graphics 640  Windows 10 S    1.25  2589.00        2.5
# 200        Nvidia GeForce GTX 1080    Windows 10    3.49  6099.00        2.9
# 885           Nvidia GeForce 940MX    Windows 10    1.23  1849.00        2.7
# 498          Intel HD Graphics 620    Windows 10    1.05  2799.00        2.7
# 195          Intel HD Graphics 500    Windows 10    1.30   260.00        1.1
# 521           Nvidia GeForce MX150         No OS    1.95  1399.95        1.8
#
#      Risoluzione    Pixel  SolidStateDisk
# 1207   1920x1080  2073600            True
# 18     2880x1800  5184000            True
# 1081   1920x1080  2073600            True
# 428    2736x1824  4990464           False
# 731    3840x2160  8294400            True
# 630     1366x768  1049088            True
# 444    2400x1600  3840000            True
# 758    1920x1080  2073600            True
# 219    2160x1440  3110400            True
# 686    1920x1080  2073600            True
# 617    3840x2160  8294400            True
# 181    1920x1080  2073600            True
# 587    1920x1080  2073600            True
# 456    2256x1504  3393024            True
# 200    3840x2160  8294400            True
# 885    1920x1080  2073600            True
# 498    1920x1080  2073600            True
# 195    1920x1080  2073600           False
# 521    1920x1080  2073600            True

# %%
df=pd.read_csv("laptop2.csv",encoding = "ISO-8859-1",index_col=0)

# %% [markdown]
# ### Creo variabile compagnia della scheda grafica

# %%
re.split("(\s)",df["Gpu"][1])[0]
# Out:
# 'Intel'

# %%
GpuCompany=[]
for i in df["Gpu"]:
    Com=re.split("(\s)",i)[0]
    GpuCompany.append(Com)
df["GpuCompany"]=GpuCompany

# %% [markdown]
# ### Memoria totale (SSD)

# %%
MemoriaSSD = []
s=re.compile("(\d+)GB SSD")
for r in df["Memory"]:
    a=s.findall(r)
    if a == [] : MemoriaSSD.append(0)
    else: MemoriaSSD.append(int(a[0]))
df["MemoriaSSD"]=MemoriaSSD

# %% [markdown]
# ### Converto la memoria da TB a GB

# %%
def TBtoGB(m):
# Funzione che prende re.match e restituisce una stringa con TB convertiti in GB
    print(m.group(1))
    a = int(float(m.group(1)))
    return str(a*1024)+'GB'

# %%
Mem = []
for i in range(0,len(df["Memory"])):
    Mem.append(re.sub("(\d+\.*0*)TB", TBtoGB, df["Memory"].iloc[i]))
df["Memory"]=Mem

# %%
#Check
w=re.compile("TB")
list(filter(w.findall,df["Memory"]))
# Out:
# []

# %% [markdown]
# ### Creo la colonna *TotalMemory*

# %%
Mem = []
a=re.compile("\d+\d*")
for i in range(0,len(df["Memory"])):
    temp= df["Memory"].iloc[i]
    NumList=a.findall(temp)
    Tot=0
    for j in NumList:
        Tot+=int(j)
    Mem.append(Tot)
df["TotalMemory"]=Mem

# %%
df
# Out:
#      Company                                    Product            TypeName  \
# 1      Apple                                MacBook Pro           Ultrabook
# 2      Apple                                Macbook Air           Ultrabook
# 3         HP                                     250 G6            Notebook
# 4      Apple                                MacBook Pro           Ultrabook
# 5      Apple                                MacBook Pro           Ultrabook
# 6       Acer                                   Aspire 3            Notebook
# 7      Apple                                MacBook Pro           Ultrabook
# 8      Apple                                Macbook Air           Ultrabook
# 9       Asus                            ZenBook UX430UN           Ultrabook
# 10      Acer                                    Swift 3           Ultrabook
# 11        HP                                     250 G6            Notebook
# 12        HP                                     250 G6            Notebook
# 13     Apple                                MacBook Pro           Ultrabook
# 14      Dell                              Inspiron 3567            Notebook
# 15     Apple                                MacBook 12"           Ultrabook
# 16     Apple                                MacBook Pro           Ultrabook
# 17      Dell                              Inspiron 3567            Notebook
# 18     Apple                                MacBook Pro           Ultrabook
# 19    Lenovo                          IdeaPad 320-15IKB            Notebook
# 20      Dell                                     XPS 13           Ultrabook
# 21      Asus                            Vivobook E200HA             Netbook
# 22    Lenovo                         Legion Y520-15IKBN              Gaming
# 23        HP                                     255 G6            Notebook
# 24      Dell                              Inspiron 5379  2 in 1 Convertible
# 25        HP    15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)           Ultrabook
# 26      Dell                              Inspiron 3567            Notebook
# 27     Apple                                MacBook Air           Ultrabook
# 28      Dell                              Inspiron 5570            Notebook
# 29      Dell                              Latitude 5590           Ultrabook
# 30        HP                                ProBook 470            Notebook
# ...      ...                                        ...                 ...
# 1291      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1292    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
# 1293    Asus                       ZenBook UX305CA-UBM1           Ultrabook
# 1294    Dell                              Inspiron 3567            Notebook
# 1295    Acer                             Aspire ES1-531            Notebook
# 1296    Dell                              Inspiron 3552            Notebook
# 1297  Lenovo                         IdeaPad Y700-15ISK            Notebook
# 1298      HP                        Pavilion 15-AW003nv            Notebook
# 1299    Dell                              Inspiron 3567            Notebook
# 1300      HP                           Stream 11-Y000na             Netbook
# 1301    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1302  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1303  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# 1304  Lenovo                         IdeaPad 100S-14IBR            Notebook
# 1305      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1306    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
# 1307    Asus                       ZenBook UX305CA-UBM1           Ultrabook
# 1308    Dell                              Inspiron 3567            Notebook
# 1309    Acer                             Aspire ES1-531            Notebook
# 1310    Dell                              Inspiron 3552            Notebook
# 1311  Lenovo                         IdeaPad Y700-15ISK            Notebook
# 1312      HP                        Pavilion 15-AW003nv            Notebook
# 1313    Dell                              Inspiron 3567            Notebook
# 1314      HP                           Stream 11-Y000na             Netbook
# 1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1316  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1317  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# 1318  Lenovo                         IdeaPad 100S-14IBR            Notebook
# 1319      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1320    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#       Inches                            ScreenResolution  \
# 1       13.3          IPS Panel Retina Display 2560x1600
# 2       13.3                                    1440x900
# 3       15.6                           Full HD 1920x1080
# 4       15.4          IPS Panel Retina Display 2880x1800
# 5       13.3          IPS Panel Retina Display 2560x1600
# 6       15.6                                    1366x768
# 7       15.4          IPS Panel Retina Display 2880x1800
# 8       13.3                                    1440x900
# 9       14.0                           Full HD 1920x1080
# 10      14.0                 IPS Panel Full HD 1920x1080
# 11      15.6                                    1366x768
# 12      15.6                           Full HD 1920x1080
# 13      15.4          IPS Panel Retina Display 2880x1800
# 14      15.6                           Full HD 1920x1080
# 15      12.0          IPS Panel Retina Display 2304x1440
# 16      13.3          IPS Panel Retina Display 2560x1600
# 17      15.6                           Full HD 1920x1080
# 18      15.4          IPS Panel Retina Display 2880x1800
# 19      15.6                           Full HD 1920x1080
# 20      13.3   IPS Panel Full HD / Touchscreen 1920x1080
# 21      11.6                                    1366x768
# 22      15.6                 IPS Panel Full HD 1920x1080
# 23      15.6                                    1366x768
# 24      13.3             Full HD / Touchscreen 1920x1080
# 25      15.6                           Full HD 1920x1080
# 26      15.6                                    1366x768
# 27      13.3                                    1440x900
# 28      15.6                           Full HD 1920x1080
# 29      15.6                           Full HD 1920x1080
# 30      17.3                           Full HD 1920x1080
# ...      ...                                         ...
# 1291    15.6                                    1366x768
# 1292    15.6                                    1366x768
# 1293    13.3                 IPS Panel Full HD 1920x1080
# 1294    15.6                                    1366x768
# 1295    15.6                                    1366x768
# 1296    15.6                                    1366x768
# 1297    15.6                 IPS Panel Full HD 1920x1080
# 1298    15.6                           Full HD 1920x1080
# 1299    15.6                                    1366x768
# 1300    11.6                                    1366x768
# 1301    15.6                                    1366x768
# 1302    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1303    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1304    14.0                                    1366x768
# 1305    15.6                                    1366x768
# 1306    15.6                                    1366x768
# 1307    13.3                 IPS Panel Full HD 1920x1080
# 1308    15.6                                    1366x768
# 1309    15.6                                    1366x768
# 1310    15.6                                    1366x768
# 1311    15.6                 IPS Panel Full HD 1920x1080
# 1312    15.6                           Full HD 1920x1080
# 1313    15.6                                    1366x768
# 1314    11.6                                    1366x768
# 1315    15.6                                    1366x768
# 1316    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1317    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1318    14.0                                    1366x768
# 1319    15.6                                    1366x768
# 1320    15.6                                    1366x768
#
#                                        Cpu  Ram                   Memory  \
# 1                     Intel Core i5 2.3GHz    8                128GB SSD
# 2                     Intel Core i5 1.8GHz    8      128GB Flash Storage
# 3               Intel Core i5 7200U 2.5GHz    8                256GB SSD
# 4                     Intel Core i7 2.7GHz   16                512GB SSD
# 5                     Intel Core i5 3.1GHz    8                256GB SSD
# 6                  AMD A9-Series 9420 3GHz    4                500GB HDD
# 7                     Intel Core i7 2.2GHz   16      256GB Flash Storage
# 8                     Intel Core i5 1.8GHz    8      256GB Flash Storage
# 9               Intel Core i7 8550U 1.8GHz   16                512GB SSD
# 10              Intel Core i5 8250U 1.6GHz    8                256GB SSD
# 11              Intel Core i5 7200U 2.5GHz    4                500GB HDD
# 12                Intel Core i3 6006U 2GHz    4                500GB HDD
# 13                    Intel Core i7 2.8GHz   16                256GB SSD
# 14                Intel Core i3 6006U 2GHz    4                256GB SSD
# 15                  Intel Core M m3 1.2GHz    8                256GB SSD
# 16                    Intel Core i5 2.3GHz    8                256GB SSD
# 17              Intel Core i7 7500U 2.7GHz    8                256GB SSD
# 18                    Intel Core i7 2.9GHz   16                512GB SSD
# 19              Intel Core i3 7100U 2.4GHz    8               1024GB HDD
# 20              Intel Core i5 8250U 1.6GHz    8                128GB SSD
# 21             Intel Atom x5-Z8350 1.44GHz    2       32GB Flash Storage
# 22             Intel Core i5 7300HQ 2.5GHz    8  128GB SSD +  1024GB HDD
# 23            AMD E-Series E2-9000e 1.5GHz    4                500GB HDD
# 24              Intel Core i5 8250U 1.6GHz    8                256GB SSD
# 25              Intel Core i7 8550U 1.8GHz    8                256GB SSD
# 26                Intel Core i3 6006U 2GHz    4               1024GB HDD
# 27                    Intel Core i5 1.6GHz    8      128GB Flash Storage
# 28              Intel Core i5 8250U 1.6GHz    8                256GB SSD
# 29              Intel Core i7 8650U 1.9GHz    8   256GB SSD +  256GB SSD
# 30              Intel Core i5 8250U 1.6GHz    8               1024GB HDD
# ...                                    ...  ...                      ...
# 1291            Intel Core i7 6500U 2.5GHz    6               1024GB HDD
# 1292  Intel Celeron Dual Core N3050 1.6GHz    4                500GB HDD
# 1293              Intel Core M 6Y30 0.9GHz    8                512GB SSD
# 1294            Intel Core i3 7100U 2.4GHz    6               1024GB HDD
# 1295  Intel Celeron Dual Core N3060 1.6GHz    4                500GB HDD
# 1296  Intel Celeron Dual Core N3050 1.6GHz    2                500GB HDD
# 1297           Intel Core i7 6700HQ 2.6GHz    8               1024GB HDD
# 1298             AMD A9-Series 9410 2.9GHz    6            1024GB Hybrid
# 1299            Intel Core i7 7500U 2.7GHz    8               1024GB HDD
# 1300  Intel Celeron Dual Core N3060 1.6GHz    2       32GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz    4                500GB HDD
# 1302            Intel Core i7 6500U 2.5GHz    4                128GB SSD
# 1303            Intel Core i7 6500U 2.5GHz   16                512GB SSD
# 1304  Intel Celeron Dual Core N3050 1.6GHz    2       64GB Flash Storage
# 1305            Intel Core i7 6500U 2.5GHz    6               1024GB HDD
# 1306  Intel Celeron Dual Core N3050 1.6GHz    4                500GB HDD
# 1307              Intel Core M 6Y30 0.9GHz    8                512GB SSD
# 1308            Intel Core i3 7100U 2.4GHz    6               1024GB HDD
# 1309  Intel Celeron Dual Core N3060 1.6GHz    4                500GB HDD
# 1310  Intel Celeron Dual Core N3050 1.6GHz    2                500GB HDD
# 1311           Intel Core i7 6700HQ 2.6GHz    8               1024GB HDD
# 1312             AMD A9-Series 9410 2.9GHz    6            1024GB Hybrid
# 1313            Intel Core i7 7500U 2.7GHz    8               1024GB HDD
# 1314  Intel Celeron Dual Core N3060 1.6GHz    2       32GB Flash Storage
# 1315            Intel Core i7 6500U 2.5GHz    4                500GB HDD
# 1316            Intel Core i7 6500U 2.5GHz    4                128GB SSD
# 1317            Intel Core i7 6500U 2.5GHz   16                512GB SSD
# 1318  Intel Celeron Dual Core N3050 1.6GHz    2       64GB Flash Storage
# 1319            Intel Core i7 6500U 2.5GHz    6               1024GB HDD
# 1320  Intel Celeron Dual Core N3050 1.6GHz    4                500GB HDD
#
#                                Gpu       OpSys  Weight    Price  Frequenza  \
# 1     Intel Iris Plus Graphics 640       macOS    1.37  1339.69       2.30
# 2           Intel HD Graphics 6000       macOS    1.34   898.94       1.80
# 3            Intel HD Graphics 620       No OS    1.86   575.00       2.50
# 4               AMD Radeon Pro 455       macOS    1.83  2537.45       2.70
# 5     Intel Iris Plus Graphics 650       macOS    1.37  1803.60       3.10
# 6                    AMD Radeon R5  Windows 10    2.10   400.00       3.00
# 7          Intel Iris Pro Graphics    Mac OS X    2.04  2139.97       2.20
# 8           Intel HD Graphics 6000       macOS    1.34  1158.70       1.80
# 9             Nvidia GeForce MX150  Windows 10    1.30  1495.00       1.80
# 10          Intel UHD Graphics 620  Windows 10    1.60   770.00       1.60
# 11           Intel HD Graphics 620       No OS    1.86   393.90       2.50
# 12           Intel HD Graphics 520       No OS    1.86   344.99       2.00
# 13              AMD Radeon Pro 555       macOS    1.83  2439.97       2.80
# 14              AMD Radeon R5 M430  Windows 10    2.20   498.90       2.00
# 15           Intel HD Graphics 615       macOS    0.92  1262.40       1.20
# 16    Intel Iris Plus Graphics 640       macOS    1.37  1518.55       2.30
# 17              AMD Radeon R5 M430  Windows 10    2.20   745.00       2.70
# 18              AMD Radeon Pro 560       macOS    1.83  2858.00       2.90
# 19            Nvidia GeForce 940MX       No OS    2.20   499.00       2.40
# 20          Intel UHD Graphics 620  Windows 10    1.22   979.00       1.60
# 21           Intel HD Graphics 400  Windows 10    0.98   191.90       1.44
# 22         Nvidia GeForce GTX 1050  Windows 10    2.50   999.00       2.50
# 23                   AMD Radeon R2       No OS    1.86   258.00       1.50
# 24          Intel UHD Graphics 620  Windows 10    1.62   819.00       1.60
# 25           Intel HD Graphics 620  Windows 10    1.91   659.00       1.80
# 26           Intel HD Graphics 520  Windows 10    2.30   418.64       2.00
# 27          Intel HD Graphics 6000    Mac OS X    1.35  1099.00       1.60
# 28                  AMD Radeon 530  Windows 10    2.20   800.00       1.60
# 29          Intel UHD Graphics 620  Windows 10    1.88  1298.00       1.90
# 30            Nvidia GeForce 930MX  Windows 10    2.50   896.00       1.60
# ...                            ...         ...     ...      ...        ...
# 1291            AMD Radeon R5 M330  Windows 10    2.19   764.00       2.50
# 1292             Intel HD Graphics  Windows 10    2.20   369.00       1.60
# 1293         Intel HD Graphics 515  Windows 10    1.20   729.00       0.90
# 1294         Intel HD Graphics 620  Windows 10    2.30   459.00       2.40
# 1295         Intel HD Graphics 400       Linux    2.40   289.00       1.60
# 1296             Intel HD Graphics  Windows 10    2.20   379.00       1.60
# 1297       Nvidia GeForce GTX 960M  Windows 10    2.60   899.00       2.60
# 1298            AMD Radeon R7 M440  Windows 10    2.04   549.99       2.90
# 1299            AMD Radeon R5 M430       Linux    2.30   805.99       2.70
# 1300         Intel HD Graphics 400  Windows 10    1.17   209.00       1.60
# 1301           Nvidia GeForce 920M  Windows 10    2.20   720.32       2.50
# 1302         Intel HD Graphics 520  Windows 10    1.80   638.00       2.50
# 1303         Intel HD Graphics 520  Windows 10    1.30  1499.00       2.50
# 1304             Intel HD Graphics  Windows 10    1.50   229.00       1.60
# 1305            AMD Radeon R5 M330  Windows 10    2.19   764.00       2.50
# 1306             Intel HD Graphics  Windows 10    2.20   369.00       1.60
# 1307         Intel HD Graphics 515  Windows 10    1.20   729.00       0.90
# 1308         Intel HD Graphics 620  Windows 10    2.30   459.00       2.40
# 1309         Intel HD Graphics 400       Linux    2.40   289.00       1.60
# 1310             Intel HD Graphics  Windows 10    2.20   379.00       1.60
# 1311       Nvidia GeForce GTX 960M  Windows 10    2.60   899.00       2.60
# 1312            AMD Radeon R7 M440  Windows 10    2.04   549.99       2.90
# 1313            AMD Radeon R5 M430       Linux    2.30   805.99       2.70
# 1314         Intel HD Graphics 400  Windows 10    1.17   209.00       1.60
# 1315           Nvidia GeForce 920M  Windows 10    2.20   720.32       2.50
# 1316         Intel HD Graphics 520  Windows 10    1.80   638.00       2.50
# 1317         Intel HD Graphics 520  Windows 10    1.30  1499.00       2.50
# 1318             Intel HD Graphics  Windows 10    1.50   229.00       1.60
# 1319            AMD Radeon R5 M330  Windows 10    2.19   764.00       2.50
# 1320             Intel HD Graphics  Windows 10    2.20   369.00       1.60
#
#      Risoluzione    Pixel  SolidStateDisk  TotalMemory  MemoriaSSD GpuCompany
# 1      2560x1600  4096000            True          128         128      Intel
# 2       1440x900  1296000           False          128           0      Intel
# 3      1920x1080  2073600            True          256         256      Intel
# 4      2880x1800  5184000            True          512         512        AMD
# 5      2560x1600  4096000            True          256         256      Intel
# 6       1366x768  1049088           False          500           0        AMD
# 7      2880x1800  5184000           False          256           0      Intel
# 8       1440x900  1296000           False          256           0      Intel
# 9      1920x1080  2073600            True          512         512     Nvidia
# 10     1920x1080  2073600            True          256         256      Intel
# 11      1366x768  1049088           False          500           0      Intel
# 12     1920x1080  2073600           False          500           0      Intel
# 13     2880x1800  5184000            True          256         256        AMD
# 14     1920x1080  2073600            True          256         256        AMD
# 15     2304x1440  3317760            True          256         256      Intel
# 16     2560x1600  4096000            True          256         256      Intel
# 17     1920x1080  2073600            True          256         256        AMD
# 18     2880x1800  5184000            True          512         512        AMD
# 19     1920x1080  2073600           False         1024           0     Nvidia
# 20     1920x1080  2073600            True          128         128      Intel
# 21      1366x768  1049088           False           32           0      Intel
# 22     1920x1080  2073600            True         1152         128     Nvidia
# 23      1366x768  1049088           False          500           0        AMD
# 24     1920x1080  2073600            True          256         256      Intel
# 25     1920x1080  2073600            True          256         256      Intel
# 26      1366x768  1049088           False         1024           0      Intel
# 27      1440x900  1296000           False          128           0      Intel
# 28     1920x1080  2073600            True          256         256        AMD
# 29     1920x1080  2073600            True          512         256      Intel
# 30     1920x1080  2073600           False         1024           0     Nvidia
# ...          ...      ...             ...          ...         ...        ...
# 1291    1366x768  1049088           False         1024           0        AMD
# 1292    1366x768  1049088           False          500           0      Intel
# 1293   1920x1080  2073600            True          512         512      Intel
# 1294    1366x768  1049088           False         1024           0      Intel
# 1295    1366x768  1049088           False          500           0      Intel
# 1296    1366x768  1049088           False          500           0      Intel
# 1297   1920x1080  2073600           False         1024           0     Nvidia
# 1298   1920x1080  2073600           False         1024           0        AMD
# 1299    1366x768  1049088           False         1024           0        AMD
# 1300    1366x768  1049088           False           32           0      Intel
# 1301    1366x768  1049088           False          500           0     Nvidia
# 1302   1920x1080  2073600            True          128         128      Intel
# 1303   3200x1800  5760000            True          512         512      Intel
# 1304    1366x768  1049088           False           64           0      Intel
# 1305    1366x768  1049088           False         1024           0        AMD
# 1306    1366x768  1049088           False          500           0      Intel
# 1307   1920x1080  2073600            True          512         512      Intel
# 1308    1366x768  1049088           False         1024           0      Intel
# 1309    1366x768  1049088           False          500           0      Intel
# 1310    1366x768  1049088           False          500           0      Intel
# 1311   1920x1080  2073600           False         1024           0     Nvidia
# 1312   1920x1080  2073600           False         1024           0        AMD
# 1313    1366x768  1049088           False         1024           0        AMD
# 1314    1366x768  1049088           False           32           0      Intel
# 1315    1366x768  1049088           False          500           0     Nvidia
# 1316   1920x1080  2073600            True          128         128      Intel
# 1317   3200x1800  5760000            True          512         512      Intel
# 1318    1366x768  1049088           False           64           0      Intel
# 1319    1366x768  1049088           False         1024           0        AMD
# 1320    1366x768  1049088           False          500           0      Intel
#
# [1303 rows x 19 columns]

# %%
df.to_csv("Laptop2.csv")
